# %%
# %load_ext autoreload
# %autoreload 2

# %%
import datetime
import scanpy as sc
import lineagevi as linvi
import os

processed_path = '/Users/lgolinelli/git/lineageVI/notebooks/data/inputs/anndata/processed'
output_base_path = '/Users/lgolinelli/git/lineageVI/notebooks/data/outputs'
dataset_name = 'pancreas'
time = datetime.datetime.now().strftime("%Y.%m.%d_%H.%M.%S")
output_dir_name =f'{dataset_name}_{time}'
output_dir_path = os.path.join(output_base_path, output_dir_name)
input_adata_path = os.path.join(processed_path, dataset_name+ '.h5ad')
adata = sc.read_h5ad(input_adata_path)

model = linvi.trainer.LineageVI(
    adata,
    n_hidden=128,
    mask_key="I",
    gene_prior=True,
    unspliced_key="unspliced",
    spliced_key="spliced",
)

history = model.fit(
    K=10,
    batch_size=1024,
    lr=1e-3,
    epochs1=50,
    epochs2=50,
    shuffle_regime1=True,
    shuffle_regime2=False,
    seeds=(0, 1, 2),
    output_dir=output_dir_path,
    verbose=1,
)

z = model.get_latent()
adata_out = model.get_adata()
# Out:
# [Regime1] Epoch 1/50 - Loss: 45.5577
# [Regime1] Epoch 2/50 - Loss: 45.4420
# [Regime1] Epoch 3/50 - Loss: 45.3131
# [Regime1] Epoch 4/50 - Loss: 45.1495
# [Regime1] Epoch 5/50 - Loss: 44.9483
# [Regime1] Epoch 6/50 - Loss: 44.7098
# [Regime1] Epoch 7/50 - Loss: 44.4425
# [Regime1] Epoch 8/50 - Loss: 44.1489
# [Regime1] Epoch 9/50 - Loss: 43.8327
# [Regime1] Epoch 10/50 - Loss: 43.4978
# [Regime1] Epoch 11/50 - Loss: 43.1454
# [Regime1] Epoch 12/50 - Loss: 42.7763
# [Regime1] Epoch 13/50 - Loss: 42.3910
# [Regime1] Epoch 14/50 - Loss: 41.9925
# [Regime1] Epoch 15/50 - Loss: 41.5861
# [Regime1] Epoch 16/50 - Loss: 41.1682
# [Regime1] Epoch 17/50 - Loss: 40.7466
# [Regime1] Epoch 18/50 - Loss: 40.3208
# [Regime1] Epoch 19/50 - Loss: 39.8932
# [Regime1] Epoch 20/50 - Loss: 39.4655
# [Regime1] Epoch 21/50 - Loss: 39.0344
# [Regime1] Epoch 22/50 - Loss: 38.6034
# [Regime1] Epoch 23/50 - Loss: 38.1708
# [Regime1] Epoch 24/50 - Loss: 37.7383
# [Regime1] Epoch 25/50 - Loss: 37.3068
# [Regime1] Epoch 26/50 - Loss: 36.8745
# [Regime1] Epoch 27/50 - Loss: 36.4470
# [Regime1] Epoch 28/50 - Loss: 36.0243
# [Regime1] Epoch 29/50 - Loss: 35.6052
# [Regime1] Epoch 30/50 - Loss: 35.1917
# [Regime1] Epoch 31/50 - Loss: 34.7865
# [Regime1] Epoch 32/50 - Loss: 34.3875
# [Regime1] Epoch 33/50 - Loss: 33.9962
# [Regime1] Epoch 34/50 - Loss: 33.6089
# [Regime1] Epoch 35/50 - Loss: 33.2288
# [Regime1] Epoch 36/50 - Loss: 32.8546
# [Regime1] Epoch 37/50 - Loss: 32.4752
# [Regime1] Epoch 38/50 - Loss: 32.0856
# [Regime1] Epoch 39/50 - Loss: 31.7110
# [Regime1] Epoch 40/50 - Loss: 31.3395
# [Regime1] Epoch 41/50 - Loss: 30.9772
# [Regime1] Epoch 42/50 - Loss: 30.6093
# [Regime1] Epoch 43/50 - Loss: 30.2538
# [Regime1] Epoch 44/50 - Loss: 29.9013
# [Regime1] Epoch 45/50 - Loss: 29.5628
# [Regime1] Epoch 46/50 - Loss: 29.2327
# [Regime1] Epoch 47/50 - Loss: 28.9123
# [Regime1] Epoch 48/50 - Loss: 28.5980
# [Regime1] Epoch 49/50 - Loss: 28.2965
# [Regime1] Epoch 50/50 - Loss: 28.0004
# [Regime2] Epoch 1/50 - Velocity Loss: 0.4889
# [Regime2] Epoch 2/50 - Velocity Loss: 0.4471
# [Regime2] Epoch 3/50 - Velocity Loss: 0.4272
# [Regime2] Epoch 4/50 - Velocity Loss: 0.4135
# [Regime2] Epoch 5/50 - Velocity Loss: 0.4039
# [Regime2] Epoch 6/50 - Velocity Loss: 0.3971
# [Regime2] Epoch 7/50 - Velocity Loss: 0.3924
# [Regime2] Epoch 8/50 - Velocity Loss: 0.3891
# [Regime2] Epoch 9/50 - Velocity Loss: 0.3865
# [Regime2] Epoch 10/50 - Velocity Loss: 0.3846
# [Regime2] Epoch 11/50 - Velocity Loss: 0.3830
# [Regime2] Epoch 12/50 - Velocity Loss: 0.3816
# [Regime2] Epoch 13/50 - Velocity Loss: 0.3804
# [Regime2] Epoch 14/50 - Velocity Loss: 0.3793
# [Regime2] Epoch 15/50 - Velocity Loss: 0.3783
# [Regime2] Epoch 16/50 - Velocity Loss: 0.3775
# [Regime2] Epoch 17/50 - Velocity Loss: 0.3766
# [Regime2] Epoch 18/50 - Velocity Loss: 0.3758
# [Regime2] Epoch 19/50 - Velocity Loss: 0.3751
# [Regime2] Epoch 20/50 - Velocity Loss: 0.3744
# [Regime2] Epoch 21/50 - Velocity Loss: 0.3736
# [Regime2] Epoch 22/50 - Velocity Loss: 0.3730
# [Regime2] Epoch 23/50 - Velocity Loss: 0.3723
# [Regime2] Epoch 24/50 - Velocity Loss: 0.3717
# [Regime2] Epoch 25/50 - Velocity Loss: 0.3711
# [Regime2] Epoch 26/50 - Velocity Loss: 0.3705
# [Regime2] Epoch 27/50 - Velocity Loss: 0.3700
# [Regime2] Epoch 28/50 - Velocity Loss: 0.3694
# [Regime2] Epoch 29/50 - Velocity Loss: 0.3689
# [Regime2] Epoch 30/50 - Velocity Loss: 0.3683
# [Regime2] Epoch 31/50 - Velocity Loss: 0.3678
# [Regime2] Epoch 32/50 - Velocity Loss: 0.3673
# [Regime2] Epoch 33/50 - Velocity Loss: 0.3669
# [Regime2] Epoch 34/50 - Velocity Loss: 0.3664
# [Regime2] Epoch 35/50 - Velocity Loss: 0.3660
# [Regime2] Epoch 36/50 - Velocity Loss: 0.3655
# [Regime2] Epoch 37/50 - Velocity Loss: 0.3651
# [Regime2] Epoch 38/50 - Velocity Loss: 0.3647
# [Regime2] Epoch 39/50 - Velocity Loss: 0.3642
# [Regime2] Epoch 40/50 - Velocity Loss: 0.3638
# [Regime2] Epoch 41/50 - Velocity Loss: 0.3633
# [Regime2] Epoch 42/50 - Velocity Loss: 0.3630
# [Regime2] Epoch 43/50 - Velocity Loss: 0.3627
# [Regime2] Epoch 44/50 - Velocity Loss: 0.3625
# [Regime2] Epoch 45/50 - Velocity Loss: 0.3623
# [Regime2] Epoch 46/50 - Velocity Loss: 0.3619
# [Regime2] Epoch 47/50 - Velocity Loss: 0.3614
# [Regime2] Epoch 48/50 - Velocity Loss: 0.3610
# [Regime2] Epoch 49/50 - Velocity Loss: 0.3605
# [Regime2] Epoch 50/50 - Velocity Loss: 0.3601
# Saved AnnData → /Users/lgolinelli/git/lineageVI/notebooks/data/outputs/pancreas_2025.08.24_12.36.47/adata_with_velocity.h5ad
# Saved model  → /Users/lgolinelli/git/lineageVI/notebooks/data/outputs/pancreas_2025.08.24_12.36.47/vae_velocity_model.pt

# %%
import scvelo as scv

# %%
'''
# -------------------- Example usage --------------------
if __name__ == "__main__":
    processed_path = '/Users/lgolinelli/git/lineageVI/notebooks/data/inputs/anndata/processed'
    output_base_path = '/Users/lgolinelli/git/lineageVI/notebooks/data/outputs'
    dataset_name = 'pancreas.h5ad'
    time = datetime.now().strftime("%Y.%m.%d_%H.%M.%S")
    output_dir_name =f'{dataset_name}_{time}'
    output_dir_path = os.path.join(output_base_path, output_dir_name)
    input_adata_path = os.path.join(processed_path, dataset_name)
    adata = sc.read_h5ad(input_adata_path)

    model = linvi.model.LineageVI(
        adata,
        n_hidden=128,
        mask_key="I",
        gene_prior=True,
        seed=0,
        unspliced_key="unspliced",
        spliced_key="spliced",
    )

    history = model.fit(
        K=10,
        batch_size=1024,
        lr=1e-3,
        epochs1=50,
        epochs2=50,
        shuffle_regime1=True,
        shuffle_regime2=False,
        seeds=(0, 1, 2),
        output_dir=output_dir_path,
        verbose=1,
    )

    z = model.get_latent()
    adata_out = model.get_adata()'''
# Out:
# '\n# -------------------- Example usage --------------------\nif __name__ == "__main__":\n    processed_path = \'/Users/lgolinelli/git/lineageVI/notebooks/data/inputs/anndata/processed\'\n    output_base_path = \'/Users/lgolinelli/git/lineageVI/notebooks/data/outputs\'\n    dataset_name = \'pancreas.h5ad\'\n    time = datetime.now().strftime("%Y.%m.%d_%H.%M.%S")\n    output_dir_name =f\'{dataset_name}_{time}\'\n    output_dir_path = os.path.join(output_base_path, output_dir_name)\n    input_adata_path = os.path.join(processed_path, dataset_name)\n    adata = sc.read_h5ad(input_adata_path)\n\n    model = linvi.model.LineageVI(\n        adata,\n        n_hidden=128,\n        mask_key="I",\n        gene_prior=True,\n        seed=0,\n        unspliced_key="unspliced",\n        spliced_key="spliced",\n    )\n\n    history = model.fit(\n        K=10,\n        batch_size=1024,\n        lr=1e-3,\n        epochs1=50,\n        epochs2=50,\n        shuffle_regime1=True,\n        shuffle_regime2=False,\n        seeds=(0, 1, 2),\n        output_dir=output_dir_path,\n        verbose=1,\n    )\n\n    z = model.get_latent()\n    adata_out = model.get_adata()'
